# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# The correlation between mouse weight and the average tumor volume is 0.53 tell us that there is a strong correlation between weight and tumor volume.  The scatter plot for Capomulin tends to confirm this as well.  Capomulin and Ramicane appear to be the most consistent with success in treatments as they do not pose any outliers and their average tumor volumes are relatively low when compared to other regimens.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_data_df = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="outer")
# Display the data table for preview
combined_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
combined_data_df["Mouse ID"].nunique()
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
combined_data_df.duplicated().sum()
# Out:
# 1

# %%
# Optional: Get all the data for the duplicate mouse ID. 
combined_data_df[combined_data_df.duplicated()]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909                45.0                 0

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = combined_data_df.drop_duplicates()
cleaned_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
cleaned_df["Mouse ID"].nunique()
# Out:
# 249

# %%
cleaned_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
cleaned_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
regimen_df = cleaned_df.loc[:, ["Mouse ID","Drug Regimen","Tumor Volume (mm3)"]]
mean = regimen_df.groupby(["Drug Regimen"]).mean()["Tumor Volume (mm3)"]
median = regimen_df.groupby(["Drug Regimen"]).median()["Tumor Volume (mm3)"]
variance = regimen_df.groupby(["Drug Regimen"]).var()["Tumor Volume (mm3)"]
sd = regimen_df.groupby(["Drug Regimen"]).std()["Tumor Volume (mm3)"]
sem = regimen_df.groupby(["Drug Regimen"]).sem()["Tumor Volume (mm3)"]
summary_df = pd.DataFrame({"mean tv":mean,"median tv":median,"variance":variance, "SD": sd, "SEM": sem})

# Assemble the resulting series into a single summary dataframe.
summary_df
# Out:
#                 mean tv  median tv   variance        SD       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.368318  50.909965  42.278090  6.502160  0.514041
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
grouped_df = cleaned_df.groupby('Drug Regimen')
grouped_agg_df = grouped_df.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
# Using the aggregation method, produce the same summary statistics in a single line
grouped_agg_df
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.368318  50.909965  42.278090  6.502160  0.514041
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
regimen_df
# Out:
#      Mouse ID Drug Regimen  Tumor Volume (mm3)
# 0        k403     Ramicane           45.000000
# 1        k403     Ramicane           38.825898
# 2        k403     Ramicane           35.014271
# 3        k403     Ramicane           34.223992
# 4        k403     Ramicane           32.997729
# ...       ...          ...                 ...
# 1888     z969     Naftisol           63.145652
# 1889     z969     Naftisol           65.841013
# 1890     z969     Naftisol           69.176246
# 1891     z969     Naftisol           70.314904
# 1892     z969     Naftisol           73.867845
#
# [1892 rows x 3 columns]

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pandas.
total_mice = cleaned_df["Drug Regimen"].value_counts()
total_mice
# Out:
# Capomulin    230
# Ramicane     228
# Ketapril     188
# Naftisol     186
# Zoniferol    182
# Placebo      181
# Stelasyn     181
# Infubinol    178
# Ceftamin     178
# Propriva     160
# Name: Drug Regimen, dtype: int64

# %%
# y = total_mice.values
# x = total_mice.index
total_mice.plot(kind="bar", facecolor="blue")
plt.ylabel("Mice")
plt.xlabel("Drug Regimen")
plt.title("Mice Tested")
plt.show()

# %%
# Generate a bar plot showing the total number of unique mice tested on each drug regimen using pyplot.
#pyplot bar chart
total_mice 

x = total_mice.index.values
# values = total_mice.values
# values
height = total_mice.values
height
regimens = total_mice.index.values
# regimens

# %%
plt.bar(x, height)

#aesthetics
# plt.title()
plt.ylabel("Number of Treatments")
plt.xlabel("Drugs")
plt.xticks(rotation=90)

plt.show()

# %%
cleaned_df["Sex"]
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#         ...
# 1888    Male
# 1889    Male
# 1890    Male
# 1891    Male
# 1892    Male
# Name: Sex, Length: 1892, dtype: object

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
#pandas
sex = cleaned_df["Sex"].value_counts()
sex.plot(kind="pie",autopct="%1.1f%%")

plt.show()

# %%
sex
# Out:
# Male      958
# Female    934
# Name: Sex, dtype: int64

# %%
labels=sex.index.values
labels
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
#pyplot
labels=sex.index.values
plt.pie(sex, labels=labels)
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
max_tumor = cleaned_df.groupby(["Mouse ID"])["Timepoint"].max()
max_tumor = max_tumor.reset_index()
print(max_tumor)
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
merged_data = max_tumor.merge(cleaned_df,on=["Mouse ID","Timepoint"],how="left")
merged_data
# Out:
#     Mouse ID  Timepoint
# 0       a203         45
# 1       a251         45
# 2       a262         45
# 3       a275         45
# 4       a366         30
# ..       ...        ...
# 244     z435         10
# 245     z578         45
# 246     z581         45
# 247     z795         45
# 248     z969         45
#
# [249 rows x 2 columns]
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 244     z435         10     Propriva  Female          12          26
# 245     z578         45     Ramicane    Male          11          16
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatment_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in treatment_list:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    final_tumor_vol = merged_data.loc[merged_data["Drug Regimen"] == drug, "Tumor Volume (mm3)"]
    
    # add subset 
    tumor_vol.append(final_tumor_vol)
    
    # Determine outliers using upper and lower bounds
    quartiles = final_tumor_vol.quantile([.25, .5, .75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    outliers = final_tumor_vol.loc[(final_tumor_vol < lower_bound) | (final_tumor_vol > upper_bound)]
    print(f"{drug}'s potential outliers: {outliers})")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64))
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64))
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64)
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64))

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
orange_out = dict(markerfacecolor='green',markersize=15)
plt.boxplot(tumor_vol, labels = treatment_list,flierprops=orange_out)
plt.ylabel('Final Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
capomulin_table = cleaned_df.loc[cleaned_df['Drug Regimen'] == 'Capomulin']
mousedata = capomulin_table.loc[capomulin_table['Mouse ID'] == 'r157']
plt.plot(mousedata['Timepoint'],mousedata['Tumor Volume (mm3)'])
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Capomulin Treatment of Mouse r157')
plt.show()

# %%
capomulin_table
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10       s185    Capomulin  Female           3          17          0
# 11       s185    Capomulin  Female           3          17          5
# 12       s185    Capomulin  Female           3          17         10
# 13       s185    Capomulin  Female           3          17         15
# 14       s185    Capomulin  Female           3          17         20
# ...       ...          ...     ...         ...         ...        ...
# 440      i557    Capomulin  Female           1          24         45
# 1452     r157    Capomulin    Male          22          25          0
# 1453     r157    Capomulin    Male          22          25          5
# 1454     r157    Capomulin    Male          22          25         10
# 1455     r157    Capomulin    Male          22          25         15
#
#       Tumor Volume (mm3)  Metastatic Sites
# 10             45.000000                 0
# ...

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
capomulin_tumor_vol = capomulin_table["Tumor Volume (mm3)"] 
mouse_weight = capomulin_table["Weight (g)"]
capomulin_average = capomulin_table["Tumor Volume (mm3)"].mean()
capomulin_average

plt.scatter(capomulin_tumor_vol, mouse_weight, marker="o", facecolors="red", edgecolors="black",
            s=capomulin_tumor_vol, alpha=0.75)
plt.xlabel('Capomulin Tumor Volume')
plt.ylabel('Mouse Weight')
plt.show()

# %% [markdown]
# # Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
corr=round(st.pearsonr(capomulin_table['Weight (g)'], capomulin_table['Tumor Volume (mm3)'])[0],2)
print(f"The correlation between mouse weight and the average tumor volume is {corr}")
model = st.linregress(capomulin_table['Weight (g)'], capomulin_table['Tumor Volume (mm3)'])

y_values = capomulin_table['Weight (g)']*model[0]+model[1]
plt.scatter(capomulin_table['Weight (g)'],capomulin_table['Tumor Volume (mm3)'])
plt.plot(capomulin_table['Weight (g)'],y_values,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.53
